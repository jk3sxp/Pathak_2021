# %%
import numpy as np
import scipy
import h5py
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from simulation_data import get
from simulation_data.galaxies import GalaxyPopulation
my_galaxy_population = GalaxyPopulation()
from simulation_data.galaxies.galaxy import age_profile, get_star_formation_history, get_galaxy_particle_data, get_stellar_assembly_data, metallicity_profile, metals_profile, avg_abundance, total_stellar_mass

redshift = 4

# %%
with h5py.File('galaxy_population_data_'+str(redshift)+'.hdf5', 'r') as f:
    ids = f['ids'][:]
    median_age = f['median_age'][:]
    halfmass_radius = f['halfmass_radius'][:]
    total_mass = f['total_mass'][:]
    newbin_current_SFR = f['newbin_current_SFR'][:]
    FeH_Re = f['FeH_Re'][:]
    MgFe_Re = f['MgFe_Re'][:]
    MgH_Re = f['MgH_Re'][:]
    FeH_1kpc = f['FeH_1kpc'][:]
    MgFe_1kpc = f['MgFe_1kpc'][:]
    MgH_1kpc = f['MgH_1kpc'][:]

# %%
# axes limits
M_lim = [10.5, 12]
logRe_lim = [-0.7, 1.94]
MRe_lim = [9.36, 11.89]
FeHRe_lim = [-0.39, 0.53]
FeH1kpc_lim = [-0.3, 0.53]
MgFeRe_lim = [0.21, 0.55]
MgFe1kpc_lim = [0.16, 0.55]
MgHRe_lim = [-0.03, 0.77]
MgH1kpc_lim = [0.16, 0.54]
age_lim = [0, 2.5]
ageabundance_lim = [-1.8, 0.9]
bigage_lim = [0, 1]

# %%
import warnings
warnings.filterwarnings('ignore')

# z=2 parameters
# 1.2 -> 0.8 Gyr
# 1.5 -> 1.0 Gyr
# -10.5 -> -9.5
PSB_selection = (median_age<=0.8)&(np.log10(newbin_current_SFR/10**(total_mass))<=-9.5)
intermediate_quiescent_selection = (median_age>0.8)&(median_age<=1.0)&(np.log10(newbin_current_SFR/10**(total_mass))<=-9.5)
old_quiescent_selection = (median_age>1.0)&(np.log10(newbin_current_SFR/10**(total_mass))<=-9.5)
starforming_selection = (np.log10(newbin_current_SFR/10**(total_mass))>-9.5)

# %%
print(len(ids[starforming_selection]))
print(len(ids[PSB_selection]))
print(len(ids[intermediate_quiescent_selection]))
print(len(ids[old_quiescent_selection]))
# Out:
# 0
# 335
# 27
# 2

# %% [markdown]
# # download z=4 galaxies

# %%
#this initializes the values in simulation_data.galaxies.galaxy_population
# id_dict = {}
# id_dict[0] = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=10.5, mass_max=10.8)
# id_dict[1] = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=10.8, mass_max=11.1)
# id_dict[2] = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=11.1, mass_max=11.4)
# id_dict[3] = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=11.4, mass_max=11.7)
# id_dict[4] = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=11.7, mass_max=12.0)

id_range = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=10.5, mass_max=12.0)
print(len(id_range))

for idx in id_range:
    get_galaxy_particle_data(id=idx, redshift=redshift, populate_dict=False)

#this gets and saves the particle data for each galaxy in our selection
# ids = []
# for b in id_dict:
#     np.random.seed(13)
#     for idx in np.random.choice(id_dict[b], 10, replace=False):
#         ids.append(idx)
#         #get_galaxy_particle_data(id=idx, redshift=redshift, populate_dict=False)
# Out:
# http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/?mass_stars__gt=2.14212688699806&mass_stars__lt=67.74
# 96
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/0
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/450
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/451
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/672
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1121
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1291
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1292
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1570
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1736
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1737
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/1924
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/2102
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/2330
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/2560
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/2780
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/2997
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3144
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3145
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3264
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3426
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3610
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3729
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3819
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/3960
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/4318
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/4711
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5053
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5180
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5290
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5381
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5504
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5581
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/5664
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/6077
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/6309
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/6406
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/6483
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/6717
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/7182
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/7272
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/8241
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/8787
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/8910
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/8991
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/9054
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/9318
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/9380
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/9545
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/9954
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10032
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10090
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10429
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10633
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10768
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10817
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/10917
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11007
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11082
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11175
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11340
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11386
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11460
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11518
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11565
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11639
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/11761
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/12440
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/12682
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/12818
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/12881
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/13183
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/13372
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/13459
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/13998
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/14120
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/14176
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/14409
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15029
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15135
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15519
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15686
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15812
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/15894
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/16284
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/16436
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/16559
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/18688
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/18727
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/20713
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/20848
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/21667
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/21773
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/22426
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/23910
# Downloading http://www.tng-project.org/api/TNG100-1/snapshots/z=4/subhalos/24069

# %%
#this initializes the values in simulation_data.galaxies.galaxy_population
ids = my_galaxy_population.select_galaxies(redshift=redshift, mass_min=10.5, mass_max=12)
print(len(ids))

#calculate halo properties and store calculated data
my_galaxy_population.get_galaxy_population_data()
# Out:
# 96
# 96
# {'ids': array([    0,     1,   450,   451,   672,  1121,  1291,  1292,  1570,
#          1736,  1737,  1924,  2102,  2330,  2560,  2780,  2997,  3144,
#          3145,  3264,  3426,  3610,  3729,  3819,  3960,  4318,  4711,
#          5053,  5180,  5290,  5381,  5504,  5581,  5664,  6077,  6309,
#          6406,  6483,  6717,  7182,  7272,  8241,  8787,  8910,  8991,
#          9054,  9318,  9380,  9545,  9954, 10032, 10090, 10429, 10633,
#         10768, 10817, 10917, 11007, 11082, 11175, 11340, 11386, 11460,
#         11518, 11565, 11639, 11761, 12440, 12682, 12818, 12881, 13183,
#         13372, 13459, 13998, 14120, 14176, 14409, 15029, 15135, 15519,
#         15686, 15812, 15894, 16284, 16436, 16559, 18688, 18727, 20713,
#         20848, 21667, 21773, 22426, 23910, 24069]),
#  'median_age': array([0.44129114, 0.19514444, 0.43955576, 0.39816492, 0.17408625,
#         0.22500809, 0.41582234, 0.25470387, 0.27812873, 0.38436127,
#         0.25810517, 0.36542718, 0.18884531, 0.35496051, 0.23719905,
#         0.3504327 , 0.19711172, 0.32311655, 0.22688083, 0.1853988 ,
#         0.35315148, 0.30721437, 0.35937158, 0.43051713, 0.36117155,
#         0.22747268, 0.16465667, 0.34210488, 0.21670685, 0.44951134,
#         0.19696058, 0.14801686, 0.38329898, 0.38111433, 0.32253237,
#         0.26048795, 0.21648334, 0.137328  , 0.32582737, 0.22599294,
#         0.26574374, 0.30139136, 0.34723642, 0.20975697, 0.28422194,
#         0.29121812, 0.33309006, 0.51699312, 0.22035454, 0.24903999,
#         0.44152245, 0.33640825, 0.21491664, 0.41864958, 0.28209498,
#         0.38967442, 0.20058568, 0.28585007, 0.32575879, 0.35675021,
#         0.21325495, 0.2553559 , 0.25622459, 0.20070363, 0.40735545,
#         0.36575912, 0.3445384 , 0.3301388 , 0.29325758, 0.31370318,
#         0.45139318, 0.38514497, 0.3631682 , 0.33559221, 0.07248716,
#         0.31667615, 0.36409888, 0.45222508, 0.15636102, 0.32053751,
#         0.26839941, 0.37954921, 0.3870045 , 0.14727274, 0.18663762,
#         0.39848768, 0.19078368, 0.32959211, 0.45602282, 0.20292203,
#         0.32788243, 0.33966669, 0.4313019 , 0.20228179, 0.31440602,
#         0.27975144]),
#  'halfmass_radius': array([0.57953942, 0.45237673, 0.73135518, 0.66823147, 1.42054916,
#         0.38166519, 0.59049306, 1.38054325, 1.39052259, 2.65146147,
#         0.54529082, 0.38709773, 0.86303513, 0.38414526, 2.2126956 ,
#         0.49613227, 0.65166814, 0.58612341, 0.57599646, 0.54712135,
#         1.96513138, 0.47735459, 0.63944494, 0.62356067, 0.29250074,
#         1.63504576, 0.79509891, 0.28630056, 0.74328314, 0.31402421,
#         0.57395926, 1.26454089, 0.52394449, 0.62450546, 0.49627989,
#         0.92834367, 0.49374077, 1.53229997, 0.89483319, 3.30218482,
#         0.40817833, 1.27381163, 0.9725716 , 0.75763212, 0.44650133,
#         0.27540596, 0.9190434 , 0.40655447, 1.56223797, 1.54307647,
#         0.64821376, 0.90918217, 1.24095069, 1.00354296, 1.03120756,
#         0.44162976, 0.6486271 , 0.59822852, 2.76111603, 0.41172129,
#         0.52636552, 0.9918512 , 0.80221435, 0.39300266, 0.39574845,
#         0.75031001, 1.66377325, 2.01674048, 1.02232064, 1.6638323 ,
#         0.42057868, 0.40555063, 1.50894597, 0.8423974 , 0.42914083,
#         1.19208739, 0.80186005, 0.53737821, 0.73156185, 1.42046058,
#         0.51827576, 1.91526425, 0.80044287, 1.07646885, 1.41018601,
#         0.38323   , 0.60304104, 0.54995571, 0.5300561 , 0.58001181,
#         0.45196339, 0.35373487, 0.41045173, 0.47130204, 0.43661057,
#         0.67779746]),
#  'total_mass': array([11.2459372 , 10.87186272, 11.51524165, 10.58914193, 10.61512155,
#         11.38848518, 10.90311964, 10.5380699 , 11.10471145, 10.64781364,
#         10.88915277, 11.18614221, 11.06812887, 10.54613303, 10.55979499,
#         10.74728953, 11.28823906, 11.03190438, 10.80074568, 10.83115007,
#         10.62253278, 11.20994696, 11.03756999, 10.63347889, 10.90137803,
#         10.57133706, 10.992188  , 11.10501108, 10.93614138, 11.1541688 ,
#         10.63243547, 10.94819473, 11.03942407, 11.06488114, 11.09777901,
#         10.94993857, 11.06959786, 10.53055964, 10.72606369, 10.5965208 ,
#         11.05704374, 10.77462901, 10.8050425 , 10.82925913, 10.98303723,
#         10.78185286, 10.68247764, 10.82097632, 10.55472534, 10.66833171,
#         10.88271255, 10.73103817, 10.56726503, 10.7787951 , 10.61024638,
#         10.79208653, 10.65796208, 10.78405308, 10.60508832, 10.70865746,
#         10.77783271, 10.65288471, 10.7370301 , 10.76656585, 10.68085907,
#         10.78757111, 10.57805758, 10.59261696, 10.71294233, 10.55307604,
#         10.6297535 , 10.71532224, 10.53702301, 10.58575371, 10.58473407,
#         10.54001009, 10.54061613, 10.59257436, 10.6876648 , 10.57269569,
#         10.65973687, 10.51491267, 10.63575258, 10.53666168, 10.53581866,
#         10.6154154 , 10.6786396 , 10.61871034, 10.7119877 , 10.529699  ,
#         10.5122994 , 10.54211649, 10.53811447, 10.5035603 , 10.51073572,
#         10.53016452]),
#  'newbin_current_SFR': array([0.70967259, 1.33407522, 0.505012  , 1.05372634, 1.64014118,
#         1.16342852, 0.92403965, 1.80810451, 1.01495324, 1.05777817,
#         1.1370142 , 0.41243059, 1.18742563, 0.53874172, 1.35689425,
#         0.30936424, 0.93619004, 0.65213327, 0.80255601, 1.79945345,
#         1.00532813, 0.47823465, 0.10255571, 0.68922691, 0.3249451 ,
#         1.66699623, 0.71868823, 0.72544821, 0.9680003 , 0.51112912,
#         1.93486346, 1.89029195, 0.80164159, 0.61992081, 1.00763184,
#         0.43089729, 0.96839567, 2.36455598, 0.60192394, 1.56495131,
#         0.60767194, 0.80131103, 1.07846315, 1.13479051, 0.62132959,
#         1.14507664, 1.55980688, 0.63752657, 1.35615436, 0.78642134,
#         1.06611238, 3.49544907, 1.59502842, 1.2738928 , 1.09974842,
#         0.95116278, 0.85137056, 0.74940245, 0.93225288, 0.37452423,
#         2.96527846, 0.95560671, 0.5814373 , 1.23917603, 1.33778235,
#         1.15441864, 0.79007465, 0.69239279, 1.13987922, 0.9040224 ,
#         0.43229989, 0.57966041, 0.87978175, 0.98277366, 4.0172203 ,
#         1.15847594, 1.06935595, 0.75205651, 1.53438646, 0.6911119 ,
#         0.6690566 , 0.53863294, 0.76788026, 2.03990951, 1.40988958,
#         0.59055099, 0.72178299, 1.32917043, 0.53462668, 0.72916855,
#         1.27435943, 1.83671878, 0.60683108, 0.96410215, 0.50654759,
#         0.82117577]),
#  'FeH_Re': array([ 0.13892637,  0.0661118 ,  0.22031985,  0.14545655, -0.11736585,
#          0.08882274,  0.07250956, -0.20758171,  0.0828887 , -0.10698227,
#          0.12126432,  0.16078685,  0.10577204,  0.08002812, -0.22459996,
#          0.04966433,  0.08363456,  0.10769905,  0.14755942,  0.02885821,
#          0.0083591 ,  0.16921736,  0.10195819,  0.02495424,  0.14192738,
#         -0.2248227 ,  0.06503904,  0.07611419,  0.17761761,  0.12525587,
#         -0.10330986, -0.06947966,  0.08704998,  0.1329387 ,  0.07334205,
#          0.13029177,  0.11616475, -0.27537021,  0.05537306, -0.31584084,
#          0.03186721,  0.04090708,  0.03680304,  0.11786202,  0.21370906,
#          0.07237302,  0.00366706,  0.11555519, -0.17534967,  0.01721892,
#          0.08025219, -0.17690454, -0.21054487,  0.03083606, -0.09045814,
#          0.15930073,  0.05917839,  0.11098307, -0.14758606,  0.12837438,
#         -0.0481086 ,  0.06195542,  0.05189262,  0.08795235,  0.05915513,
#          0.13240324, -0.1349228 , -0.11371215, -0.03774953, -0.10648113,
#          0.0318965 ,  0.17024013, -0.07003953, -0.06020718, -0.22558153,
#         -0.09384405, -0.07705584,  0.09784087, -0.01395449, -0.06202624,
#          0.07480253, -0.10743707,  0.01755784, -0.20232457, -0.19575523,
#          0.10241159,  0.10543789,  0.06835105, -0.0269006 ,  0.07955266,
#         -0.01598887,  0.00349772,  0.02708627, -0.01930304, -0.04402874,
#         -0.10502716]),
#  'MgFe_Re': array([0.4010312 , 0.42070144, 0.37948573, 0.38603941, 0.51102024,
#         0.41211092, 0.40798733, 0.47469467, 0.41473201, 0.45964444,
#         0.41474038, 0.39253953, 0.42009392, 0.38346127, 0.50838196,
#         0.43054911, 0.430648  , 0.37744176, 0.40360427, 0.46774897,
#         0.44217056, 0.39549151, 0.42203102, 0.42079967, 0.37903467,
#         0.46692735, 0.46172288, 0.4108516 , 0.4234989 , 0.36812544,
#         0.46537709, 0.4766337 , 0.42857811, 0.39539409, 0.3941333 ,
#         0.44106433, 0.42655265, 0.51819146, 0.42479512, 0.48389027,
#         0.39750686, 0.42612919, 0.41854912, 0.42872331, 0.38365978,
#         0.40065828, 0.40933552, 0.354112  , 0.4665761 , 0.4467009 ,
#         0.39940438, 0.46188313, 0.46799397, 0.4134379 , 0.41475403,
#         0.40453047, 0.42446131, 0.39460263, 0.46028298, 0.38072169,
#         0.45032874, 0.44584912, 0.43429622, 0.43409628, 0.39061806,
#         0.38379714, 0.43851194, 0.47380614, 0.43076354, 0.45694318,
#         0.39868465, 0.36326212, 0.42655346, 0.426415  , 0.54139942,
#         0.43946499, 0.42886123, 0.38512716, 0.46114919, 0.4443118 ,
#         0.4109163 , 0.47432992, 0.41445243, 0.50215709, 0.51169485,
#         0.37129423, 0.44153562, 0.38819024, 0.40710545, 0.43874085,
#         0.40156704, 0.42424905, 0.39830109, 0.42817989, 0.41760954,
#         0.41538891]),
#  'MgH_Re': array([0.49935183, 0.46416536, 0.54058057, 0.46279356, 0.3169536 ,
#         0.47665745, 0.42657596, 0.22851096, 0.42954463, 0.24139817,
#         0.52544016, 0.50049412, 0.48820862, 0.41221574, 0.19949301,
#         0.40655535, 0.48507947, 0.4634133 , 0.51494503, 0.46708441,
#         0.37820855, 0.51001209, 0.46817181, 0.39150983, 0.49053016,
#         0.21534127, 0.50116193, 0.44634044, 0.54869866, 0.46427253,
#         0.34877506, 0.38025886, 0.45951563, 0.49862012, 0.45104349,
#         0.50428534, 0.51961929, 0.22841398, 0.41148931, 0.14517805,
#         0.41265938, 0.41814679, 0.40797785, 0.49745393, 0.55314916,
#         0.46043426, 0.35119203, 0.42868805, 0.26224649, 0.4253425 ,
#         0.41900146, 0.27206549, 0.21541627, 0.418695  , 0.29086751,
#         0.50782603, 0.4596718 , 0.47129855, 0.24100636, 0.45952931,
#         0.38962722, 0.45023057, 0.43082699, 0.4766916 , 0.42188048,
#         0.47913891, 0.24353454, 0.27330846, 0.35815662, 0.29783115,
#         0.37882206, 0.4848592 , 0.30122483, 0.31811956, 0.30742106,
#         0.29086396, 0.29850978, 0.40367603, 0.42147306, 0.31823459,
#         0.4397935 , 0.26551962, 0.37588277, 0.25631285, 0.29430181,
#         0.44432583, 0.49273276, 0.40991962, 0.33632666, 0.44500554,
#         0.37148443, 0.41276908, 0.39260551, 0.39086032, 0.33707833,
#         0.28520992]),
#  'FeH_1kpc': array([ 0.08775938, -0.02499159,  0.20039943,  0.09625317, -0.04787989,
#          0.03351182,  0.05371129, -0.16703801,  0.12171429,  0.03003573,
#          0.0652817 ,  0.10015954,  0.09242348, -0.01826406, -0.10829318,
#          0.02286405,  0.04623005,  0.06384454,  0.07141588, -0.04667812,
#          0.12800545,  0.11643675,  0.05102411, -0.00563187,  0.06168304,
#         -0.17904375,  0.04099241,  0.04149143,  0.13291408,  0.0754295 ,
#         -0.15387875, -0.03153497,  0.06512153,  0.08629321,  0.02559493,
#          0.12136135,  0.05013425, -0.21582867,  0.0428769 , -0.20887636,
#         -0.02444708,  0.07405435,  0.03337214,  0.07072158,  0.13530129,
#         -0.02059435, -0.00741729,  0.0287539 , -0.13375439,  0.05325416,
#          0.05216061, -0.18449129, -0.18189545,  0.03137073, -0.08592746,
#          0.09336737, -0.0075929 ,  0.06425508,  0.00199402,  0.02760972,
#         -0.15179212,  0.06036155,  0.033394  , -0.01580446, -0.01722402,
#          0.10237074, -0.10365069, -0.03673783, -0.03685712, -0.00871922,
#         -0.01107519,  0.08104828, -0.00255952, -0.08339482, -0.29115766,
#         -0.06011831, -0.10128538,  0.02553636, -0.05998574, -0.02555679,
#         -0.01126616, -0.00476999, -0.0014056 , -0.19583288, -0.16386151,
#          0.01106461,  0.05137198, -0.01589899,  0.02148995, -0.00036691,
#         -0.1370963 , -0.09930354, -0.04680707, -0.13731124, -0.12031467,
#         -0.1373958 ]),
#  'MgFe_1kpc': array([0.4030515 , 0.44246045, 0.38318741, 0.40268651, 0.50599486,
#         0.41816384, 0.40543967, 0.47010323, 0.41144848, 0.45010635,
#         0.41885757, 0.3948839 , 0.42078549, 0.41128027, 0.49846211,
#         0.41900322, 0.43748102, 0.37987885, 0.41766489, 0.47263664,
#         0.4270345 , 0.40372151, 0.43465403, 0.41921788, 0.39989135,
#         0.4587048 , 0.46244478, 0.39272824, 0.43092376, 0.37195826,
#         0.47131422, 0.47557485, 0.41949666, 0.39879897, 0.4001447 ,
#         0.44263095, 0.43187931, 0.51607418, 0.42748809, 0.47214553,
#         0.40571734, 0.42131057, 0.4191719 , 0.43204758, 0.40670606,
#         0.42411029, 0.41136557, 0.36476269, 0.46331778, 0.44120827,
#         0.39535734, 0.46161136, 0.45584038, 0.41338658, 0.41427785,
#         0.41089711, 0.43382552, 0.40767652, 0.45238584, 0.40965354,
#         0.46942696, 0.44603857, 0.43483648, 0.46078131, 0.41249216,
#         0.39165094, 0.43756446, 0.46443757, 0.43086633, 0.45021376,
#         0.39327812, 0.39368275, 0.41894126, 0.4256109 , 0.54822862,
#         0.43621051, 0.42980766, 0.40814862, 0.4639433 , 0.44010058,
#         0.42813963, 0.45544142, 0.41928959, 0.50279725, 0.51017874,
#         0.39948729, 0.45264375, 0.40704152, 0.38813552, 0.45909476,
#         0.4135173 , 0.444859  , 0.39831078, 0.45192733, 0.42866689,
#         0.41759014]),
#  'MgH_1kpc': array([0.44668216, 0.38125542, 0.52262086, 0.42014143, 0.37773243,
#         0.42185062, 0.40350705, 0.26459569, 0.46284381, 0.35614914,
#         0.47063053, 0.43523884, 0.47530934, 0.32187113, 0.29592717,
#         0.36209229, 0.45133162, 0.41954166, 0.44521213, 0.39550889,
#         0.48704448, 0.45320565, 0.4217768 , 0.36210078, 0.41379842,
#         0.25784799, 0.47778434, 0.38313496, 0.50707799, 0.40812364,
#         0.30130729, 0.41681427, 0.43507445, 0.4536556 , 0.40510851,
#         0.49606532, 0.45552295, 0.28720137, 0.40063417, 0.24589549,
#         0.35539201, 0.44863781, 0.40483937, 0.45365626, 0.4825494 ,
#         0.37291783, 0.34166712, 0.34870461, 0.30272946, 0.45954135,
#         0.38643709, 0.26394013, 0.23339449, 0.41921258, 0.29506096,
#         0.43834984, 0.39701653, 0.42902163, 0.37728611, 0.36895213,
#         0.29719079, 0.44880617, 0.41200313, 0.3793999 , 0.35428205,
#         0.45149136, 0.27111629, 0.34018892, 0.3591933 , 0.38818279,
#         0.32723916, 0.40753719, 0.36133787, 0.29770902, 0.24862069,
#         0.31968191, 0.2766715 , 0.34326735, 0.37689164, 0.35002428,
#         0.3595092 , 0.35190895, 0.35898712, 0.26243424, 0.3285836 ,
#         0.36142033, 0.44606349, 0.33423349, 0.37035108, 0.3760303 ,
#         0.25410157, 0.3196626 , 0.31941777, 0.28329828, 0.25965101,
#         0.25560343]),
#  'gas_mass_1kpc': array([1.10826445e+10, 5.11142356e+09, 1.13705971e+10, 2.62019738e+09,
#         2.79369143e+09, 1.74846405e+10, 5.37066610e+09, 3.72363171e+09,
#         3.45355345e+09, 1.72211839e+09, 4.45600643e+09, 6.02490415e+09,
#         5.14793113e+09, 2.16452890e+09, 2.09438426e+09, 2.69238793e+09,
#         1.13117981e+10, 6.08454805e+09, 2.98501815e+09, 5.95550449e+09,
#         1.01583363e+09, 5.72026003e+09, 3.78384477e+07, 3.77848096e+09,
#         3.10819269e+09, 4.97422980e+09, 4.58594088e+09, 9.85613636e+09,
#         3.24200524e+09, 6.29152093e+09, 4.79958671e+09, 8.75563090e+09,
#         7.79690059e+09, 6.54837436e+09, 1.04353038e+10, 2.03241321e+09,
#         7.83913306e+09, 5.23990192e+09, 1.97922188e+09, 3.71217734e+09,
#         4.83519407e+09, 3.22307390e+09, 2.66836193e+09, 3.40670343e+09,
#         2.74777429e+09, 4.11299022e+09, 3.12268241e+09, 5.59378100e+09,
#         3.14607706e+09, 2.14803691e+09, 5.84406516e+09, 1.06451334e+10,
#         3.48055792e+09, 4.46576297e+09, 2.74744848e+09, 2.07209237e+09,
#         2.96675996e+09, 2.00244410e+09, 1.29592629e+09, 3.15112432e+09,
#         9.76458044e+09, 1.76260414e+09, 2.92602529e+09, 3.34666643e+09,
#         5.22933822e+09, 2.76027468e+09, 1.17533799e+09, 1.15541611e+09,
#         3.76664280e+09, 2.29763184e+09, 2.70506993e+09, 1.25336561e+09,
#         2.40814897e+09, 2.87744654e+09, 8.95409296e+09, 3.53297469e+09,
#         2.96446766e+09, 1.74840646e+09, 7.19730828e+09, 1.80381192e+09,
#         2.79963000e+09, 1.57995124e+09, 2.53740818e+09, 4.89142057e+09,
#         3.26578463e+09, 2.05131662e+09, 2.50859891e+09, 4.00664898e+09,
#         4.44936735e+09, 8.94016314e+08, 5.19288046e+09, 5.09499525e+09,
#         2.84490772e+09, 4.44059239e+09, 2.72541968e+09, 4.33883336e+09]),
#  'stellar_mass_1kpc': array([1.20560326e+11, 5.10874166e+10, 1.81838764e+11, 2.38149749e+10,
#         1.63894839e+10, 1.76918857e+11, 5.25309331e+10, 1.32503015e+10,
#         5.39853552e+10, 1.46146442e+10, 5.17057835e+10, 1.22861965e+11,
#         6.20446847e+10, 2.60925941e+10, 1.22913777e+10, 4.59592136e+10,
#         1.15296271e+11, 7.19117867e+10, 4.33671872e+10, 4.48778351e+10,
#         1.29672619e+10, 1.14247834e+11, 6.74694678e+10, 2.85310957e+10,
#         6.60336177e+10, 1.51842597e+10, 5.49906350e+10, 1.11644235e+11,
#         5.15676747e+10, 1.28682074e+11, 2.82726440e+10, 3.85387342e+10,
#         8.05927131e+10, 7.75406127e+10, 9.64189351e+10, 4.61647465e+10,
#         7.95904182e+10, 1.22680258e+10, 2.78917381e+10, 6.03046339e+09,
#         8.01632815e+10, 2.57813365e+10, 3.21844141e+10, 4.02249953e+10,
#         7.03631627e+10, 4.78429724e+10, 2.50588460e+10, 5.70959296e+10,
#         1.13225589e+10, 1.92844295e+10, 4.79327771e+10, 2.84712008e+10,
#         1.66742342e+10, 2.99309808e+10, 1.99778849e+10, 4.97232957e+10,
#         2.99223063e+10, 3.81018417e+10, 9.85830092e+09, 4.14551515e+10,
#         4.32044583e+10, 2.25724927e+10, 3.29179792e+10, 4.52720732e+10,
#         3.72321472e+10, 3.56600705e+10, 1.44263294e+10, 1.38555109e+10,
#         2.52596700e+10, 1.10340539e+10, 3.73037548e+10, 3.85339107e+10,
#         1.09558037e+10, 2.22135849e+10, 2.72937850e+10, 1.50747236e+10,
#         2.08774911e+10, 2.70140737e+10, 3.03547298e+10, 1.46188168e+10,
#         3.20832970e+10, 1.08534130e+10, 2.32096343e+10, 1.62547188e+10,
#         1.28662860e+10, 3.21217870e+10, 3.28923280e+10, 2.96745713e+10,
#         4.10475246e+10, 2.28859316e+10, 2.59563546e+10, 2.90639147e+10,
#         2.56813812e+10, 2.69648824e+10, 2.56230233e+10, 2.40833935e+10])}

# %%
fig = plt.figure(1,figsize=(17,21))
fig.clf()
markersize = 6
fts = 20
fts_s = 17

gs0 = gridspec.GridSpec(5, 1)#,left=0.03, right=0.94,top=0.92,bottom=0.09,wspace=0.3,hspace=0.3)

gs = {}
xx = [total_mass, np.log10(halfmass_radius), np.log10(10**total_mass / halfmass_radius), np.log10(halfmass_radius), median_age]
yy_Re = [FeH_Re, MgFe_Re, MgH_Re]
yy_1kpc = [FeH_1kpc, MgFe_1kpc, MgH_1kpc]
xlim = [M_lim, logRe_lim, MRe_lim, logRe_lim, bigage_lim]
ylim_Re = [FeHRe_lim, MgFeRe_lim, MgHRe_lim]
ylim_1kpc = [FeH1kpc_lim, MgFe1kpc_lim, MgH1kpc_lim]
xlabel = ['log($M_{\star}/M_{\odot}$)', 'log($R_e$) [kpc]', 'log($M/R_e)$ $[M_{\odot}/kpc]$', 'log($R_e$) [kpc]', 'Median Stellar Age (Gyr)']
ylabel_Re = ['[Fe/H]', '[Mg/Fe]', '[Mg/H]']
ylabel_1kpc = ['[Fe/H]$_{1kpc}$', '[Mg/Fe]$_{1kpc}$', '[Mg/H]$_{1kpc}$']

for m in range(5):
    gs[m] = gridspec.GridSpecFromSubplotSpec(1, 3, subplot_spec=gs0[m])

for m in range(5):
    for k in range(3):
        ax = plt.subplot(gs[m][k])
        
        if m == 3:
            yy = yy_1kpc
            ylabel = ylabel_1kpc
            ylim = ylim_1kpc
        else:
            yy = yy_Re
            ylabel = ylabel_Re
            ylim = ylim_Re
        
        plt.plot(xx[m], yy[k], 'b.', alpha=0.4, label='star-forming', markersize=markersize, zorder=4)
        
#         yy1 = yy[k][starforming_selection]
#         xx1 = xx[m][starforming_selection]
#         plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', markersize=markersize, zorder=4)

#         yy2 = yy[k][PSB_selection]
#         xx2 = xx[m][PSB_selection]
#         plt.plot(xx2, yy2, 'r.', alpha=0.2, label='young quiescent', markersize=markersize)

#         yy3 = yy[k][intermediate_quiescent_selection]
#         xx3 = xx[m][intermediate_quiescent_selection]
#         plt.plot(xx3, yy3, 'rx', alpha=0.2, label='intermediate quies.', markersize=markersize)

#         yy4 = yy[k][old_quiescent_selection]
#         xx4 = xx[m][old_quiescent_selection]
#         plt.plot(xx4, yy4, 'rv', alpha=0.2, label='old quiescent', markersize=markersize)
        
        ax.set_xlim(xlim[m][0], xlim[m][1])
        ax.set_ylim(ylim[k][0], ylim[k][1])
        ax.set_xlabel(xlabel[m], fontsize=fts)
        ax.set_ylabel(ylabel[k], fontsize=fts)
        ax.tick_params(labelsize=fts_s)
        
#         if k==2 and m==0:
#             ax.legend(fontsize=fts_s-2)
        
fig.suptitle('Scaling relations for $z=$' + str(redshift) + ' galaxies', fontsize=fts, y=0.99)
fig.tight_layout()

# plt.savefig('FIGURES\scaling0p7.png', dpi=400)

# %% [markdown]
# ## [Fe/H]

# %%
markersize=4

plt.figure()

yy = FeH_Re
xx = total_mass

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(M_lim[0], M_lim[1])
plt.ylim(FeHRe_lim[0], FeHRe_lim[1])
plt.xlabel('log($M_{\star}/M_{\odot}$)')
plt.ylabel('[Fe/H]')
plt.legend()
plt.title('z=' + str(redshift) + ' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = FeH_Re
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(FeHRe_lim[0], FeHRe_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('[Fe/H]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = FeH_Re
xx = np.log10(10**total_mass / halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(MRe_lim[0], MRe_lim[1])
plt.ylim(FeHRe_lim[0], FeHRe_lim[1])
plt.xlabel('log($M/R_e)$ $[M_{\odot}/kpc]$')
plt.ylabel('[Fe/H]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = FeH_1kpc
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(FeH1kpc_lim[0], FeH1kpc_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('$[Fe/H]_{1 kpc}$')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
markersize = 4
ymin = -0.31
ymax = 0.48

yya = FeH_Re
yyb = FeH_1kpc
xx = np.log10(halfmass_radius)

yya1 = yya[starforming_selection]
yyb1 = yyb[starforming_selection]
xx1 = xx[starforming_selection]
ax1.plot(xx1, yya1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)
ax2.plot(xx1, yyb1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yya2 = yya[PSB_selection]
yyb2 = yyb[PSB_selection]
xx2 = xx[PSB_selection]
ax1.plot(xx2, yya2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)
ax2.plot(xx2, yyb2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yya3 = yya[intermediate_quiescent_selection]
yyb3 = yyb[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
ax1.plot(xx3, yya3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)
ax2.plot(xx3, yyb3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yya4 = yya[old_quiescent_selection]
yyb4 = yyb[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
ax1.plot(xx4, yya4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)
ax2.plot(xx4, yyb4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

ax1.set_xlabel('log($R_e$) [kpc]')
ax1.set_ylabel('[Fe/H]')
ax1.set_ylim(ymin, ymax)
ax1.tick_params(axis='y', which='minor', left=True)
ax1.tick_params(axis='both', which='both', direction='in')

ax2.set_xlabel('log($R_e$) [kpc]')
ax2.set_ylabel('$[Fe/H]_{1 kpc}$')
ax2.set_ylim(ymin, ymax)
ax2.tick_params(axis='y', which='minor', left=True)
ax2.tick_params(axis='both', which='both', direction='in')
ax2.legend()

f.suptitle('z=' + str(redshift) +' galaxies')

f.tight_layout()

# %%
markersize=4

plt.figure()

yy = FeH_Re
xx = median_age

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

#plt.xlim(bigage_lim[0], bigage_lim[1])
plt.ylim(FeHRe_lim[0], FeHRe_lim[1])
plt.xlabel('Median Stellar Age (Gyr)')
plt.ylabel('[Fe/H]')
plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %% [markdown]
# ## [Mg/Fe]

# %%
markersize=4

plt.figure()

yy = MgFe_Re
xx = total_mass

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(M_lim[0], M_lim[1])
plt.ylim(MgFeRe_lim[0], MgFeRe_lim[1])
plt.xlabel('log($M_{\star}/M_{\odot}$)')
plt.ylabel('[Mg/Fe]')
plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgFe_Re
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(MgFeRe_lim[0], MgFeRe_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('[Mg/Fe]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgFe_Re
xx = np.log10(10**total_mass / halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(MRe_lim[0], MRe_lim[1])
plt.ylim(MgFeRe_lim[0], MgFeRe_lim[1])
plt.xlabel('log($M/R_e)$ $[M_{\odot}/kpc]$')
plt.ylabel('[Mg/Fe]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgFe_1kpc
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(MgFe1kpc_lim[0], MgFe1kpc_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('$[Mg/Fe]_{1 kpc}$')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgFe_Re
xx = median_age

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

#plt.xlim(bigage_lim[0], bigage_lim[1])
plt.ylim(MgFeRe_lim[0], MgFeRe_lim[1])
plt.xlabel('Median Stellar Age (Gyr)')
plt.ylabel('[Mg/Fe]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %% [markdown]
# ## [Mg/H]

# %%
markersize=4

plt.figure()

yy = MgH_Re
xx = total_mass

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(M_lim[0], M_lim[1])
plt.ylim(MgHRe_lim[0], MgHRe_lim[1])
plt.xlabel('log($M_{\star}/M_{\odot}$)')
plt.ylabel('[Mg/H]')
plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgH_Re
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(MgHRe_lim[0], MgHRe_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('[Mg/H]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgH_Re
xx = np.log10(10**total_mass / halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(MRe_lim[0], MRe_lim[1])
plt.ylim(MgHRe_lim[0], MgHRe_lim[1])
plt.xlabel('log($M/R_e)$ $[M_{\odot}/kpc]$')
plt.ylabel('[Mg/H]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgFe_1kpc
xx = np.log10(halfmass_radius)

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(logRe_lim[0], logRe_lim[1])
plt.ylim(MgH1kpc_lim[0], MgH1kpc_lim[1])
plt.xlabel('log($R_e$) [kpc]')
plt.ylabel('$[Mg/H]_{1 kpc}$')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')

# %%
markersize=4

plt.figure()

yy = MgH_Re
xx = median_age

yy1 = yy[starforming_selection]
xx1 = xx[starforming_selection]
plt.plot(xx1, yy1, 'b.', alpha=0.4, label='star-forming', zorder=4, markersize=markersize)

yy2 = yy[PSB_selection]
xx2 = xx[PSB_selection]
plt.plot(xx2, yy2, 'r.', alpha=0.4, label='young quiescent', markersize=markersize)

yy3 = yy[intermediate_quiescent_selection]
xx3 = xx[intermediate_quiescent_selection]
plt.plot(xx3, yy3, 'rx', alpha=0.4, label='intermediate quiescent', markersize=markersize)

yy4 = yy[old_quiescent_selection]
xx4 = xx[old_quiescent_selection]
plt.plot(xx4, yy4, 'rv', alpha=0.4, label='old quiescent', markersize=markersize)

plt.xlim(bigage_lim[0], bigage_lim[1])
plt.ylim(MgHRe_lim[0], MgHRe_lim[1])
plt.xlabel('Median Stellar Age (Gyr)')
plt.ylabel('[Mg/H]')
#plt.legend()
plt.title('z='+str(redshift)+' galaxies')
# Out:
# Text(0.5, 1.0, 'z=3 galaxies')
